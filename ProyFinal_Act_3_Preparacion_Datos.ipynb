# %%
####### Módulos de análisis de datos
import pandas as pd
import numpy as np

###### Bibliotecas de visualización
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import seaborn as sns   # Se puede ver la documentación de esta libreria en. https://seaborn.pydata.org/generated/seaborn.barplot.html o https://seaborn.pydata.org/generated/seaborn.catplot.html
# %matplotlib inline
import io # Provee las facilidades principales de python para manejar E/S (entradas y salidas)

####### Bibliotecas de Machine Learning
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score
from sklearn.metrics import roc_curve, auc, roc_auc_score, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score,GridSearchCV

# %%
#######Importar los data sets. con listdir se pueden ver los directorios y archivos descargados, seleccionamos los del ejercicio
from os import listdir
import os
listdir()
# Out:
# ['.config', 'sample_data']

# %%
# Cargar el dataset compartido
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-b300d8c7-2fbd-4c2c-b4a6-d8c85452c1de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b300d8c7-2fbd-4c2c-b4a6-d8c85452c1de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
for fn in uploaded.keys():
       print('User uploaded file "{name}" with length {length} bytes'.format(
           name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "Actividad_3_Dataset_completo.csv" with length 263646 bytes

# %%
# PARA INGRESAR AL CONTENIDO DEL ARCHIVO QUE SE SUBIO
data = pd.read_csv(io.StringIO(uploaded['Actividad_3_Dataset_completo.csv'].decode('ISO-8859-2')),sep=',')   # ingresa a la data del archivo que se subió

data.head(5)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
data.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
data.head(), data.describe(include='all')
# Out:
# (   Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
#  0  Female  21.0    1.62    64.0                            yes   no   2.0
#  1  Female  21.0    1.52    56.0                            yes   no   3.0
#  2    Male  23.0    1.80    77.0                            yes   no   2.0
#  3    Male  27.0    1.80    87.0                             no   no   3.0
#  4    Male  22.0    1.78    89.8                             no   no   2.0
#
#     NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
#  0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
#  1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
#  2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
#  3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
#  4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                    MTRANS           NObeyesdad
#  0  Public_Transportation        Normal_Weight
#  1  Public_Transportation        Normal_Weight
# ...

# %%
# Verificar la distribución de clases en el dataset original
clases_originales = data['NObeyesdad'].value_counts()
print(f"Distribución original de clases en NObeyesdad:\n{clases_originales}")
# Out:
# Distribución original de clases en NObeyesdad:
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %% [markdown]
# # LIMPIEZA DE DATOS

# %% [markdown]
# 1. Revisar valores nulos:
#
# Para asegurarnos de que no hay valores nulos en el dataset.

# %%
# 1. Revisar si tenemos valores nulos en el dataset

print(data.isnull().sum())
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %% [markdown]
# 2. Revisar valores únicos:
#
# Esto te permitirá ver cuántas categorías únicas tiene cada columna, lo cual es útil para identificar posibles valores anómalos.

# %%
 # Verificar valores únicos en cada columna
print(data.nunique())
# Out:
# Gender                               2
# Age                               1402
# Height                            1574
# Weight                            1525
# family_history_with_overweight       2
# FAVC                                 2
# FCVC                               810
# NCP                                635
# CAEC                                 4
# SMOKE                                2
# CH2O                              1268
# SCC                                  2
# FAF                               1190
# TUE                               1129
# CALC                                 4
# MTRANS                               5
# NObeyesdad                           7
# dtype: int64

# %% [markdown]
# 3. Filtrado de valores anómalos:
#
# Aplicaremos un filtro básico para eliminar posibles valores anómalos en las columnas de Height y Weight.

# %%
# Filtrado de valores anómalos
data_filtered = data[(data['Height'] >= 1.2) & (data['Height'] <= 2.5)]
data_filtered = data_filtered[(data_filtered['Weight'] >= 30) & (data_filtered['Weight'] <= 200)]

# %%
data_filtered.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
# Verificar la distribución de clases en el dataset filtrado
clases_originales = data_filtered['NObeyesdad'].value_counts()
print(f"Distribución original de clases en NObeyesdad:\n{clases_originales}")
# Out:
# Distribución original de clases en NObeyesdad:
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %% [markdown]
# 4. Normalización
#
# Normalizaremos las columnas numéricas Age, Height, y Weight.

# %%
from sklearn.preprocessing import StandardScaler

# Normalizar columnas numéricas
scaler = StandardScaler()
data_filtered[['Age', 'Height', 'Weight']] = scaler.fit_transform(data_filtered[['Age', 'Height', 'Weight']])

# %% [markdown]
# 5. Codificación de Variables Categóricas
#
# Convertimos las variables categóricas utilizando one-hot encoding.

# %%
# Codificación de variables categóricas
data_encoded = pd.get_dummies(data_filtered, drop_first=True)

# %%
# Revisar la codificación one-hot
data_encoded = pd.get_dummies(data, columns=['NObeyesdad'])
print(f"Columnas generadas por la codificación one-hot:\n{data_encoded.columns}")
# Out:
# Columnas generadas por la codificación one-hot:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad_Insufficient_Weight',
#        'NObeyesdad_Normal_Weight', 'NObeyesdad_Obesity_Type_I',
#        'NObeyesdad_Obesity_Type_II', 'NObeyesdad_Obesity_Type_III',
#        'NObeyesdad_Overweight_Level_I', 'NObeyesdad_Overweight_Level_II'],
#       dtype='object')

# %%
# Supongamos que estas son las columnas categóricas que necesitas codificar
columnas_categoricas = ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS']

# Aplicar la codificación one-hot
data_encoded = pd.get_dummies(data, columns=columnas_categoricas)
# Out:
# Archivo data_preparada.csv generado con éxito.

# %%
# Verificar la cantidad de valores en cada una de las columnas codificadas
cantidad_por_columna = data_encoded[['NObeyesdad_Insufficient_Weight',
                                     'NObeyesdad_Normal_Weight',
                                     'NObeyesdad_Obesity_Type_I',
                                     'NObeyesdad_Obesity_Type_II',
                                     'NObeyesdad_Obesity_Type_III',
                                     'NObeyesdad_Overweight_Level_I',
                                     'NObeyesdad_Overweight_Level_II']].sum()

print(cantidad_por_columna)
# Out:
# NObeyesdad_Insufficient_Weight    272
# NObeyesdad_Normal_Weight          287
# NObeyesdad_Obesity_Type_I         351
# NObeyesdad_Obesity_Type_II        297
# NObeyesdad_Obesity_Type_III       324
# NObeyesdad_Overweight_Level_I     290
# NObeyesdad_Overweight_Level_II    290
# dtype: int64

# %%
# Mostrar las columnas generadas por la codificación one-hot
print(f"Columnas generadas por la codificación one-hot:\n{data_encoded.columns}")
# Out:
# Columnas generadas por la codificación one-hot:
# Index(['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE',
#        'NObeyesdad', 'Gender_Female', 'Gender_Male',
#        'family_history_with_overweight_no',
#        'family_history_with_overweight_yes', 'FAVC_no', 'FAVC_yes',
#        'CAEC_Always', 'CAEC_Frequently', 'CAEC_Sometimes', 'CAEC_no',
#        'SMOKE_no', 'SMOKE_yes', 'SCC_no', 'SCC_yes', 'CALC_Always',
#        'CALC_Frequently', 'CALC_Sometimes', 'CALC_no', 'MTRANS_Automobile',
#        'MTRANS_Bike', 'MTRANS_Motorbike', 'MTRANS_Public_Transportation',
#        'MTRANS_Walking'],
#       dtype='object')

# %% [markdown]
# 6. Guardar el dataset preparado
#
# Finalmente, guardamos el dataset preparado.

# %%
# Guardar el dataset preparado
data_encoded.to_csv('data_preparada.csv', index=False)

print("Archivo data_preparada.csv generado con éxito.")
# Out:
# Archivo data_preparada.csv generado con éxito.

# %%
listdir()
# Out:
# ['.config',
#  'data_preparada.csv',
#  'Actividad_3_Dataset_completo.csv',
#  '.ipynb_checkpoints',
#  'sample_data']
